# %%
import akshare as ak
import pandas as pd

# %%
stock_sse_summary_df = ak.stock_sse_summary()
stock_sse_summary_df
# Out:
#       项目         股票         主板       科创板
# 0   流通股本    44886.7      43751   1135.71
# 1    总市值  465597.06  406237.16   59359.9
# 2  平均市盈率      12.04      11.05     34.49
# 3   上市公司       2251       1689       562
# 4   上市股票       2290       1728       562
# 5   流通市值  418512.93  382692.86  35820.07
# 6   报告时间   20231019   20231019  20231019
# 8    总股本   48895.87   46787.98   2107.89

# %%
import akshare as ak

currency_boc_sina_df = ak.currency_boc_sina(symbol="美元", start_date="20230304", end_date="20230813")
print(currency_boc_sina_df)
# Out:
#              日期   中行汇买价   中行钞买价  中行钞卖价/汇卖价   央行中间价
# 0    2023-03-06  691.80  686.17     694.73  689.51
# 1    2023-03-07  694.49  688.84     697.44  691.56
# 2    2023-03-08  693.49  687.85     696.43  695.25
# 3    2023-03-09  695.04  689.39     697.99  696.66
# 4    2023-03-10  689.70  684.09     692.62  696.55
# ..          ...     ...     ...        ...     ...
# 110  2023-08-07  718.00  712.16     720.86  713.80
# 111  2023-08-08  720.63  714.77     723.51  715.65
# 112  2023-08-09  719.79  713.94     722.66  715.88
# 113  2023-08-10  720.74  714.88     723.62  715.76
# 114  2023-08-11  722.74  716.86     725.62  715.87
#
# [115 rows x 5 columns]

# %%
import akshare as ak
import os
# import requests
# proxy = 'http://127.0.0.1:10889'
# proxies = {
#    'http': proxy,
#    'https': proxy
# }
# session = requests.Session()
# session.proxies.update(proxies)
# ak.set_proxy(session=session)
# Set the proxy server URL and port number

proxy_url = 'http://127.0.0.1'
proxy_port = '10889'

# Set the HTTP_PROXY and HTTPS_PROXY environment variables
os.environ['HTTP_PROXY'] = f'{proxy_url}:{proxy_port}'
os.environ['HTTPS_PROXY'] = f'{proxy_url}:{proxy_port}'

stock_us_hist_df = ak.stock_us_hist(symbol='105.MTP', period="daily", start_date="19700101", end_date="22220101", adjust="qfq")
print(stock_us_hist_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [22], line 21
#      18 os.environ['HTTP_PROXY'] = f'{proxy_url}:{proxy_port}'
#      19 os.environ['HTTPS_PROXY'] = f'{proxy_url}:{proxy_port}'
# ---> 21 stock_us_hist_df = ak.stock_us_hist(symbol='105.MTP', period="daily", start_date="19700101", end_date="22220101", adjust="qfq")
#      22 print(stock_us_hist_df)
#
# File D:\U\Python\lib\site-packages\akshare\stock_feature\stock_hist_em.py:1768, in stock_us_hist(symbol, period, start_date, end_date, adjust)
#    1766 r = requests.get(url, params=params)
#    1767 data_json = r.json()
# -> 1768 if not data_json["data"]["klines"]:
#    1769     return pd.DataFrame()
#    1770 temp_df = pd.DataFrame([item.split(",") for item in data_json["data"]["klines"]])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import quandl
quandl.ApiConfig.proxies = {
   'http': 'http://127.0.0.1:10889',
   'https': 'http://127.0.0.1:10889',
}
data = quandl.get("WIKI/AAPL", rows=5)
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File D:\U\Python\lib\site-packages\urllib3\connectionpool.py:696, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     695 if is_new_proxy_conn and http_tunnel_required:
# --> 696     self._prepare_proxy(conn)
#     698 # Make the request on the httplib connection object.
#
# File D:\U\Python\lib\site-packages\urllib3\connectionpool.py:964, in HTTPSConnectionPool._prepare_proxy(self, conn)
#     962     conn.tls_in_tls_required = True
# --> 964 conn.connect()
#
# File D:\U\Python\lib\site-packages\urllib3\connection.py:359, in HTTPSConnection.connect(self)
#     358 if self.tls_in_tls_required:
# --> 359     conn = self._connect_tls_proxy(hostname, conn)
#     360     tls_in_tls = True
#
# ...

# %%
from googlefinance import getQuotes
import json
print json.dumps(getQuotes('AAPL'), indent=2)
# Out:
#   Cell In [8], line 3
#     print json.dumps(getQuotes('AAPL'), indent=2)
#           ^
# SyntaxError: invalid syntax

# %%
import akshare as ak

stock_us_hist_df = ak.stock_us_hist(symbol='105.MTP', period="daily", start_date="19700101", end_date="22220101", adjust="qfq")
print(stock_us_hist_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [7], line 3
#       1 import akshare as ak
# ----> 3 stock_us_hist_df = ak.stock_us_hist(symbol='105.MTP', period="daily", start_date="19700101", end_date="22220101", adjust="qfq")
#       4 print(stock_us_hist_df)
#
# File D:\U\Python\lib\site-packages\akshare\stock_feature\stock_hist_em.py:1768, in stock_us_hist(symbol, period, start_date, end_date, adjust)
#    1766 r = requests.get(url, params=params)
#    1767 data_json = r.json()
# -> 1768 if not data_json["data"]["klines"]:
#    1769     return pd.DataFrame()
#    1770 temp_df = pd.DataFrame([item.split(",") for item in data_json["data"]["klines"]])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import akshare as ak

stock_us_daily_df = ak.stock_us_daily(symbol="AAPL", adjust="")
print(stock_us_daily_df)
# Out:
#            date    open    high     low   close      volume
# 0    1984-09-07   26.50   26.87   26.25   26.50   2981600.0
# 1    1984-09-10   26.50   26.62   25.87   26.37   2346400.0
# 2    1984-09-11   26.62   27.37   26.62   26.87   5444000.0
# 3    1984-09-12   26.87   27.00   26.12   26.12   4773600.0
# 4    1984-09-13   27.50   27.62   27.50   27.50   7429600.0
# ...         ...     ...     ...     ...     ...         ...
# 9301 2023-10-16  176.75  179.08  176.51  178.72  52516984.0
# 9302 2023-10-17  176.65  178.42  174.80  177.15  57549350.0
# 9303 2023-10-18  175.58  177.58  175.11  175.84  54764375.0
# 9304 2023-10-19  176.04  177.84  175.19  175.46  59302863.0
# 9305 2023-10-20  175.31  175.42  172.64  172.88  64244028.0
#
# [9306 rows x 6 columns]

# %%
import efinance as ef
# 股票代码
stock_code = '600519'
ef.stock.get_quote_history(stock_code)
# Out:
#       股票名称    股票代码          日期       开盘       收盘       最高       最低     成交量  \
# 0     贵州茅台  600519  2001-08-27  -159.23  -159.02  -158.58  -159.56  406318
# 1     贵州茅台  600519  2001-08-28  -159.14  -158.76  -158.74  -159.21  129647
# 2     贵州茅台  600519  2001-08-29  -158.74  -158.86  -158.74  -158.91   53252
# 3     贵州茅台  600519  2001-08-30  -158.88  -158.72  -158.63  -158.93   48013
# 4     贵州茅台  600519  2001-08-31  -158.71  -158.73  -158.61  -158.78   23231
# ...    ...     ...         ...      ...      ...      ...      ...     ...
# 5294  贵州茅台  600519  2023-10-16  1750.98  1729.90  1756.00  1722.45   20790
# 5295  贵州茅台  600519  2023-10-17  1739.00  1726.00  1739.44  1716.00   14945
# 5296  贵州茅台  600519  2023-10-18  1718.80  1728.00  1742.00  1717.18   20318
# 5297  贵州茅台  600519  2023-10-19  1700.00  1630.00  1700.03  1626.03   73492
# 5298  贵州茅台  600519  2023-10-20  1630.00  1645.00  1655.00  1616.25   45376
#
#                成交额    振幅   涨跌幅    涨跌额    换手率
# ...

# %%
import akshare as ak

stock_us_daily_df = ak.stock_us_daily(symbol="AAPL", adjust="")
print(stock_us_daily_df)
# Out:
#            date    open    high     low   close      volume
# 0    1984-09-07   26.50   26.87   26.25   26.50   2981600.0
# 1    1984-09-10   26.50   26.62   25.87   26.37   2346400.0
# 2    1984-09-11   26.62   27.37   26.62   26.87   5444000.0
# 3    1984-09-12   26.87   27.00   26.12   26.12   4773600.0
# 4    1984-09-13   27.50   27.62   27.50   27.50   7429600.0
# ...         ...     ...     ...     ...     ...         ...
# 9301 2023-10-16  176.75  179.08  176.51  178.72  52516984.0
# 9302 2023-10-17  176.65  178.42  174.80  177.15  57549350.0
# 9303 2023-10-18  175.58  177.58  175.11  175.84  54764375.0
# 9304 2023-10-19  176.04  177.84  175.19  175.46  59302863.0
# 9305 2023-10-20  175.31  175.42  172.64  172.88  64244028.0
#
# [9306 rows x 6 columns]

# %%
stock_us_daily_df.to_csv('./AAPL.csv')

# %%
df=pd.read_csv('./AAPL.csv')

# %%
df
# Out:
#       Unnamed: 0        date    open    high     low   close      volume
# 0              0  1984-09-07   26.50   26.87   26.25   26.50   2981600.0
# 1              1  1984-09-10   26.50   26.62   25.87   26.37   2346400.0
# 2              2  1984-09-11   26.62   27.37   26.62   26.87   5444000.0
# 3              3  1984-09-12   26.87   27.00   26.12   26.12   4773600.0
# 4              4  1984-09-13   27.50   27.62   27.50   27.50   7429600.0
# ...          ...         ...     ...     ...     ...     ...         ...
# 9301        9301  2023-10-16  176.75  179.08  176.51  178.72  52516984.0
# 9302        9302  2023-10-17  176.65  178.42  174.80  177.15  57549350.0
# 9303        9303  2023-10-18  175.58  177.58  175.11  175.84  54764375.0
# 9304        9304  2023-10-19  176.04  177.84  175.19  175.46  59302863.0
# 9305        9305  2023-10-20  175.31  175.42  172.64  172.88  64244028.0
#
# [9306 rows x 7 columns]

# %%
df.head()
# Out:
#    Unnamed: 0        date   open   high    low  close     volume
# 0           0  1984-09-07  26.50  26.87  26.25  26.50  2981600.0
# 1           1  1984-09-10  26.50  26.62  25.87  26.37  2346400.0
# 2           2  1984-09-11  26.62  27.37  26.62  26.87  5444000.0
# 3           3  1984-09-12  26.87  27.00  26.12  26.12  4773600.0
# 4           4  1984-09-13  27.50  27.62  27.50  27.50  7429600.0

# %%
df.drop(labels='Unnamed: 0',axis='columns',inplace=True)
df
# Out:
#             date    open    high     low   close      volume
# 0     1984-09-07   26.50   26.87   26.25   26.50   2981600.0
# 1     1984-09-10   26.50   26.62   25.87   26.37   2346400.0
# 2     1984-09-11   26.62   27.37   26.62   26.87   5444000.0
# 3     1984-09-12   26.87   27.00   26.12   26.12   4773600.0
# 4     1984-09-13   27.50   27.62   27.50   27.50   7429600.0
# ...          ...     ...     ...     ...     ...         ...
# 9301  2023-10-16  176.75  179.08  176.51  178.72  52516984.0
# 9302  2023-10-17  176.65  178.42  174.80  177.15  57549350.0
# 9303  2023-10-18  175.58  177.58  175.11  175.84  54764375.0
# 9304  2023-10-19  176.04  177.84  175.19  175.46  59302863.0
# 9305  2023-10-20  175.31  175.42  172.64  172.88  64244028.0
#
# [9306 rows x 6 columns]

# %%
df['date']=pd.to_datetime(df['date'])
df
# Out:
#            date    open    high     low   close      volume
# 0    1984-09-07   26.50   26.87   26.25   26.50   2981600.0
# 1    1984-09-10   26.50   26.62   25.87   26.37   2346400.0
# 2    1984-09-11   26.62   27.37   26.62   26.87   5444000.0
# 3    1984-09-12   26.87   27.00   26.12   26.12   4773600.0
# 4    1984-09-13   27.50   27.62   27.50   27.50   7429600.0
# ...         ...     ...     ...     ...     ...         ...
# 9301 2023-10-16  176.75  179.08  176.51  178.72  52516984.0
# 9302 2023-10-17  176.65  178.42  174.80  177.15  57549350.0
# 9303 2023-10-18  175.58  177.58  175.11  175.84  54764375.0
# 9304 2023-10-19  176.04  177.84  175.19  175.46  59302863.0
# 9305 2023-10-20  175.31  175.42  172.64  172.88  64244028.0
#
# [9306 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9306 entries, 0 to 9305
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    9306 non-null   datetime64[ns]
#  1   open    9306 non-null   float64
#  2   high    9306 non-null   float64
#  3   low     9306 non-null   float64
#  4   close   9306 non-null   float64
#  5   volume  9306 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 436.3 KB

# %%
df.set_index('date',inplace=True)
df
# Out:
#               open    high     low   close      volume
# date
# 1984-09-07   26.50   26.87   26.25   26.50   2981600.0
# 1984-09-10   26.50   26.62   25.87   26.37   2346400.0
# 1984-09-11   26.62   27.37   26.62   26.87   5444000.0
# 1984-09-12   26.87   27.00   26.12   26.12   4773600.0
# 1984-09-13   27.50   27.62   27.50   27.50   7429600.0
# ...            ...     ...     ...     ...         ...
# 2023-10-16  176.75  179.08  176.51  178.72  52516984.0
# 2023-10-17  176.65  178.42  174.80  177.15  57549350.0
# 2023-10-18  175.58  177.58  175.11  175.84  54764375.0
# 2023-10-19  176.04  177.84  175.19  175.46  59302863.0
# 2023-10-20  175.31  175.42  172.64  172.88  64244028.0
#
# [9306 rows x 5 columns]

# %%
df['open'].shift(1)
df
# Out:
#               open    high     low   close      volume
# date
# 1984-09-07   26.50   26.87   26.25   26.50   2981600.0
# 1984-09-10   26.50   26.62   25.87   26.37   2346400.0
# 1984-09-11   26.62   27.37   26.62   26.87   5444000.0
# 1984-09-12   26.87   27.00   26.12   26.12   4773600.0
# 1984-09-13   27.50   27.62   27.50   27.50   7429600.0
# ...            ...     ...     ...     ...         ...
# 2023-10-16  176.75  179.08  176.51  178.72  52516984.0
# 2023-10-17  176.65  178.42  174.80  177.15  57549350.0
# 2023-10-18  175.58  177.58  175.11  175.84  54764375.0
# 2023-10-19  176.04  177.84  175.19  175.46  59302863.0
# 2023-10-20  175.31  175.42  172.64  172.88  64244028.0
#
# [9306 rows x 5 columns]

# %%
# td's open compared to ytd's close
df.loc[(df['close']-df['open'].shift(1))/df['open'].shift(1)<-0.1].index
# Out:
# DatetimeIndex(['1985-03-07', '1985-03-08', '1985-05-24', '1985-05-28',
#                '1987-01-21', '1987-06-16', '1987-10-19', '1987-10-20',
#                '1987-10-26', '1987-10-27', '1989-06-16', '1989-12-12',
#                '1990-10-03', '1990-10-16', '1991-04-15', '1991-05-01',
#                '1993-07-16', '1993-07-19', '1993-12-10', '1995-01-23',
#                '1995-03-14', '1995-09-15', '1996-06-26', '1997-01-06',
#                '1997-07-01', '1997-08-11', '1997-08-12', '1997-10-20',
#                '1997-10-30', '1997-11-11', '1997-12-02', '1998-08-28',
#                '1998-08-31', '1999-09-21', '1999-09-28', '2000-04-12',
#                '2000-06-21', '2000-07-24', '2000-09-22', '2000-09-29',
#                '2000-10-02', '2000-10-03', '2000-10-25', '2000-12-06',
#                '2001-01-02', '2001-05-30', '2001-07-18', '2002-06-19',
#                '2002-07-17', '2007-11-09', '2007-11-12', '2008-01-16',
# ...
